# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/wkddn/OneDrive/문서/GitHub/Kaggle/kaggle/Pima Indians/diabetes.csv')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
split_count = int(df.shape[0]*0.8)
split_count
# Out:
# 614

# %%
train = df[:split_count].copy()
train.shape
# Out:
# (614, 9)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 9)

# %%
feature_names = train.columns[:-1].tolist()
feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
label_name = train.columns[-1]
label_name
# Out:
# 'Outcome'

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (614,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 8)
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 614           11      138             74             26      144  36.1
# 615            3      106             72              0        0  25.8
# 616            6      117             96              0        0  28.7
# 617            2       68             62             13       15  20.1
# 618            9      112             82             24        0  28.2
#
#      DiabetesPedigreeFunction  Age
# 614                     0.557   50
# 615                     0.207   27
# 616                     0.157   30
# 617                     0.257   23
# 618                     1.282   50

# %%
y_test = test[label_name]
print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 1, 0, 1], dtype=int64)

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=feature_names)
# Out:
# [Text(191.25032971864007, 211.04470588235293, 'Glucose <= 154.5\ngini = 0.453\nsamples = 614\nvalue = [401, 213]'),
#  Text(63.59679073856975, 198.25411764705882, 'BMI <= 26.35\ngini = 0.385\nsamples = 518\nvalue = [383, 135]'),
#  Text(12.559906213364595, 185.4635294117647, 'Glucose <= 124.5\ngini = 0.061\nsamples = 128\nvalue = [124, 4]'),
#  Text(6.279953106682298, 172.6729411764706, 'DiabetesPedigreeFunction <= 0.675\ngini = 0.019\nsamples = 105\nvalue = [104, 1]'),
#  Text(3.139976553341149, 159.88235294117646, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]'),
#  Text(9.419929660023445, 159.88235294117646, 'DiabetesPedigreeFunction <= 0.705\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(6.279953106682298, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(12.559906213364595, 147.09176470588235, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(18.83985932004689, 172.6729411764706, 'BMI <= 9.8\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(15.699882766705745, 159.88235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(21.97983587338804, 159.88235294117646, 'BloodPressure <= 56.0\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(18.83985932004689, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(25.11981242672919, 147.09176470588235, 'Age <= 58.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(21.97983587338804, 134.30117647058825, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(28.25978898007034, 134.30117647058825, 'SkinThickness <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(25.11981242672919, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(31.39976553341149, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(114.6336752637749, 185.4635294117647, 'Glucose <= 99.5\ngini = 0.446\nsamples = 390\nvalue = [259, 131]'),
#  Text(59.26705744431418, 172.6729411764706, 'Insulin <= 153.0\ngini = 0.191\nsamples = 112\nvalue = [100, 12]'),
#  Text(52.987104337631884, 159.88235294117646, 'BMI <= 50.85\ngini = 0.167\nsamples = 109\nvalue = [99, 10]'),
#  Text(49.847127784290734, 147.09176470588235, 'Glucose <= 28.5\ngini = 0.153\nsamples = 108\nvalue = [99, 9]'),
#  Text(40.81969519343493, 134.30117647058825, 'Pregnancies <= 3.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(37.67971864009378, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(43.95967174677608, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(58.87456037514654, 134.30117647058825, 'Pregnancies <= 9.5\ngini = 0.126\nsamples = 104\nvalue = [97, 7]'),
#  Text(50.23962485345838, 121.51058823529411, 'DiabetesPedigreeFunction <= 1.16\ngini = 0.097\nsamples = 98\nvalue = [93, 5]'),
#  Text(42.38968347010551, 108.72, 'DiabetesPedigreeFunction <= 0.253\ngini = 0.081\nsamples = 95\nvalue = [91, 4]'),
#  Text(36.10973036342321, 95.92941176470588, 'DiabetesPedigreeFunction <= 0.245\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(32.96975381008206, 83.13882352941175, 'SkinThickness <= 8.0\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(29.829777256740915, 70.34823529411764, 'Glucose <= 93.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(26.689800703399765, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(32.96975381008206, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(36.10973036342321, 70.34823529411764, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(39.24970691676436, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(48.66963657678781, 95.92941176470588, 'SkinThickness <= 41.0\ngini = 0.028\nsamples = 70\nvalue = [69, 1]'),
#  Text(45.52966002344666, 83.13882352941175, 'gini = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(51.80961313012895, 83.13882352941175, 'Pregnancies <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(48.66963657678781, 70.34823529411764, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(54.9495896834701, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(58.08956623681125, 108.72, 'Insulin <= 28.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(54.9495896834701, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(61.2295427901524, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(67.5094958968347, 121.51058823529411, 'Age <= 43.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(64.36951934349355, 108.72, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(70.64947245017585, 108.72, 'Insulin <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(67.5094958968347, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(73.78944900351699, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(56.12708089097303, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(65.54701055099648, 159.88235294117646, 'Glucose <= 91.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(62.40703399765533, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(68.68698710433763, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(170.00029308323565, 172.6729411764706, 'Age <= 28.5\ngini = 0.49\nsamples = 278\nvalue = [159, 119]'),
#  Text(119.31910902696366, 159.88235294117646, 'BloodPressure <= 22.0\ngini = 0.404\nsamples = 114\nvalue = [82, 32]'),
#  Text(116.1791324736225, 147.09176470588235, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(122.4590855803048, 147.09176470588235, 'BMI <= 41.8\ngini = 0.373\nsamples = 109\nvalue = [82, 27]'),
#  Text(105.18921453692849, 134.30117647058825, 'BloodPressure <= 81.0\ngini = 0.325\nsamples = 93\nvalue = [74, 19]'),
#  Text(102.04923798358733, 121.51058823529411, 'Glucose <= 127.5\ngini = 0.365\nsamples = 79\nvalue = [60, 19]'),
#  Text(86.34935521688159, 108.72, 'DiabetesPedigreeFunction <= 0.504\ngini = 0.266\nsamples = 57\nvalue = [48, 9]'),
#  Text(80.06940211019929, 95.92941176470588, 'BloodPressure <= 73.0\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(76.92942555685815, 83.13882352941175, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(83.20937866354045, 83.13882352941175, 'Insulin <= 31.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(80.06940211019929, 70.34823529411764, 'BMI <= 34.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(76.92942555685815, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(83.20937866354045, 57.557647058823534, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(86.34935521688159, 70.34823529411764, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(92.62930832356389, 95.92941176470588, 'BMI <= 32.7\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(89.48933177022273, 83.13882352941175, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(95.76928487690503, 83.13882352941175, 'BloodPressure <= 68.0\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(92.62930832356389, 70.34823529411764, 'Glucose <= 116.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(89.48933177022273, 57.557647058823534, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(95.76928487690503, 57.557647058823534, 'BloodPressure <= 51.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(92.62930832356389, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(98.90926143024619, 44.767058823529396, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(98.90926143024619, 70.34823529411764, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(117.74912075029307, 108.72, 'Glucose <= 146.5\ngini = 0.496\nsamples = 22\nvalue = [12, 10]'),
#  Text(114.60914419695193, 95.92941176470588, 'DiabetesPedigreeFunction <= 0.183\ngini = 0.494\nsamples = 18\nvalue = [8, 10]'),
#  Text(111.46916764361079, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(117.74912075029307, 83.13882352941175, 'Insulin <= 199.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(114.60914419695193, 70.34823529411764, 'BMI <= 28.8\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(108.32919109026963, 57.557647058823534, 'DiabetesPedigreeFunction <= 0.315\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(105.18921453692849, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.46916764361079, 44.767058823529396, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(120.88909730363423, 57.557647058823534, 'DiabetesPedigreeFunction <= 0.857\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(117.74912075029307, 44.767058823529396, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(124.02907385697537, 44.767058823529396, 'Insulin <= 90.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(120.88909730363423, 31.976470588235287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(127.16905041031653, 31.976470588235287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(120.88909730363423, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(120.88909730363423, 95.92941176470588, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(108.32919109026963, 121.51058823529411, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(139.7289566236811, 134.30117647058825, 'BloodPressure <= 85.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(133.44900351699883, 121.51058823529411, 'BMI <= 43.55\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(130.3090269636577, 108.72, 'Glucose <= 141.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(127.16905041031653, 95.92941176470588, 'BMI <= 42.2\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(124.02907385697537, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(130.3090269636577, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(133.44900351699883, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(136.58898007033997, 108.72, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(146.00890973036343, 121.51058823529411, 'Insulin <= 150.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(142.86893317702226, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(149.14888628370457, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(220.68147713950762, 159.88235294117646, 'DiabetesPedigreeFunction <= 0.514\ngini = 0.498\nsamples = 164\nvalue = [77, 87]'),
#  Text(187.80984759671747, 147.09176470588235, 'Age <= 58.5\ngini = 0.487\nsamples = 98\nvalue = [57, 41]'),
#  Text(184.6698710433763, 134.30117647058825, 'BloodPressure <= 93.0\ngini = 0.496\nsamples = 90\nvalue = [49, 41]'),
#  Text(181.52989449003516, 121.51058823529411, 'BloodPressure <= 67.0\ngini = 0.49\nsamples = 86\nvalue = [49, 37]'),
#  Text(155.42883939038686, 108.72, 'Insulin <= 41.5\ngini = 0.455\nsamples = 20\nvalue = [7, 13]'),
#  Text(147.57889800703398, 95.92941176470588, 'Pregnancies <= 8.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(141.2989449003517, 83.13882352941175, 'DiabetesPedigreeFunction <= 0.425\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(138.15896834701056, 70.34823529411764, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(144.43892145369284, 70.34823529411764, 'BMI <= 30.95\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(141.2989449003517, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(147.57889800703398, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(153.8588511137163, 83.13882352941175, 'BloodPressure <= 59.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(150.71887456037513, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(156.99882766705744, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(163.27878077373973, 95.92941176470588, 'Insulin <= 152.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(160.13880422039858, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(166.4187573270809, 83.13882352941175, 'Age <= 37.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(163.27878077373973, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(169.55873388042204, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(207.63094958968347, 108.72, 'BMI <= 47.95\ngini = 0.463\nsamples = 66\nvalue = [42, 24]'),
#  Text(204.49097303634233, 95.92941176470588, 'BloodPressure <= 84.5\ngini = 0.451\nsamples = 64\nvalue = [42, 22]'),
#  Text(190.7535756154748, 83.13882352941175, 'BloodPressure <= 79.0\ngini = 0.484\nsamples = 51\nvalue = [30, 21]'),
#  Text(175.83868698710432, 70.34823529411764, 'SkinThickness <= 26.5\ngini = 0.439\nsamples = 40\nvalue = [27, 13]'),
#  Text(164.8487690504103, 57.557647058823534, 'BloodPressure <= 69.0\ngini = 0.499\nsamples = 21\nvalue = [10, 11]'),
#  Text(161.70879249706917, 44.767058823529396, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(167.98874560375145, 44.767058823529396, 'Glucose <= 135.5\ngini = 0.475\nsamples = 18\nvalue = [7, 11]'),
#  Text(161.70879249706917, 31.976470588235287, 'Glucose <= 112.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(158.56881594372803, 19.185882352941178, 'DiabetesPedigreeFunction <= 0.252\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(155.42883939038686, 6.39529411764704, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(161.70879249706917, 6.39529411764704, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(164.8487690504103, 19.185882352941178, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(174.26869871043377, 31.976470588235287, 'BMI <= 37.15\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(171.1287221570926, 19.185882352941178, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(177.4086752637749, 19.185882352941178, 'BMI <= 42.2\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(174.26869871043377, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(180.54865181711605, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(186.82860492379837, 57.557647058823534, 'Pregnancies <= 14.0\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(183.6886283704572, 44.767058823529396, 'Insulin <= 294.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(180.54865181711605, 31.976470588235287, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(186.82860492379837, 31.976470588235287, 'SkinThickness <= 35.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(183.6886283704572, 19.185882352941178, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(189.9685814771395, 19.185882352941178, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(189.9685814771395, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(205.66846424384525, 70.34823529411764, 'Age <= 34.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(199.38851113716294, 57.557647058823534, 'Age <= 29.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(196.2485345838218, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(202.5284876905041, 44.767058823529396, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(211.94841735052754, 57.557647058823534, 'Glucose <= 107.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(208.8084407971864, 44.767058823529396, 'Glucose <= 104.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(205.66846424384525, 31.976470588235287, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(211.94841735052754, 31.976470588235287, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(215.08839390386868, 44.767058823529396, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(218.22837045720985, 83.13882352941175, 'Insulin <= 126.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(215.08839390386868, 70.34823529411764, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(221.368347010551, 70.34823529411764, 'BMI <= 33.45\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(218.22837045720985, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(224.50832356389213, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(210.7709261430246, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(187.80984759671747, 121.51058823529411, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(190.94982415005862, 134.30117647058825, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(253.55310668229777, 147.09176470588235, 'Pregnancies <= 7.5\ngini = 0.422\nsamples = 66\nvalue = [20, 46]'),
#  Text(241.3856975381008, 134.30117647058825, 'BMI <= 31.4\ngini = 0.485\nsamples = 46\nvalue = [19, 27]'),
#  Text(226.47080890973035, 121.51058823529411, 'Age <= 40.0\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(220.19085580304807, 108.72, 'BloodPressure <= 53.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(217.0508792497069, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(223.3308323563892, 95.92941176470588, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(232.75076201641266, 108.72, 'BloodPressure <= 65.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(229.6107854630715, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(235.8907385697538, 95.92941176470588, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(256.30058616647125, 121.51058823529411, 'SkinThickness <= 27.0\ngini = 0.412\nsamples = 31\nvalue = [9, 22]'),
#  Text(245.31066822977724, 108.72, 'Glucose <= 123.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(242.1706916764361, 95.92941176470588, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(248.4506447831184, 95.92941176470588, 'BMI <= 39.65\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(245.31066822977724, 83.13882352941175, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(251.59062133645955, 83.13882352941175, 'Age <= 34.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(248.4506447831184, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(254.7305978898007, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(267.2905041031653, 108.72, 'Insulin <= 225.0\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(261.010550996483, 95.92941176470588, 'Glucose <= 102.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(257.87057444314183, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(264.1505275498241, 83.13882352941175, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(273.5704572098476, 95.92941176470588, 'DiabetesPedigreeFunction <= 0.634\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(270.43048065650646, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(276.71043376318875, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(265.7205158264947, 134.30117647058825, 'DiabetesPedigreeFunction <= 1.289\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(262.5805392731536, 121.51058823529411, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(268.8604923798359, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(318.9038686987104, 198.25411764705882, 'Age <= 62.5\ngini = 0.305\nsamples = 96\nvalue = [18, 78]'),
#  Text(309.2876905041032, 185.4635294117647, 'Insulin <= 544.0\ngini = 0.26\nsamples = 91\nvalue = [14, 77]'),
#  Text(299.47526377491204, 172.6729411764706, 'DiabetesPedigreeFunction <= 0.3\ngini = 0.223\nsamples = 86\nvalue = [11, 75]'),
#  Text(289.2703399765533, 159.88235294117646, 'DiabetesPedigreeFunction <= 0.288\ngini = 0.403\nsamples = 25\nvalue = [7, 18]'),
#  Text(286.1303634232122, 147.09176470588235, 'Age <= 27.0\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(279.85041031652986, 134.30117647058825, 'Age <= 25.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(276.71043376318875, 121.51058823529411, 'BMI <= 29.45\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(273.5704572098476, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(279.85041031652986, 108.72, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(282.99038686987103, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(292.4103165298945, 134.30117647058825, 'Age <= 59.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(289.2703399765533, 121.51058823529411, 'Pregnancies <= 9.0\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(286.1303634232122, 108.72, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(292.4103165298945, 108.72, 'Glucose <= 177.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(289.2703399765533, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(295.5502930832356, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(295.5502930832356, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(292.4103165298945, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(309.6801875732708, 159.88235294117646, 'BloodPressure <= 51.0\ngini = 0.123\nsamples = 61\nvalue = [4, 57]'),
#  Text(301.83024618991794, 147.09176470588235, 'BMI <= 29.1\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(298.6902696365768, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(304.97022274325906, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(317.5301289566237, 147.09176470588235, 'BloodPressure <= 107.0\ngini = 0.097\nsamples = 59\nvalue = [3, 56]'),
#  Text(311.2501758499414, 134.30117647058825, 'Age <= 49.5\ngini = 0.068\nsamples = 57\nvalue = [2, 55]'),
#  Text(308.11019929660023, 121.51058823529411, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(314.3901524032825, 121.51058823529411, 'Pregnancies <= 1.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(311.2501758499414, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(317.5301289566237, 108.72, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(323.81008206330597, 134.30117647058825, 'BMI <= 36.95\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(320.6701055099648, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(326.95005861664714, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(319.10011723329427, 172.6729411764706, 'BloodPressure <= 69.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(315.9601406799531, 159.88235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(322.2400937866354, 159.88235294117646, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(328.52004689331767, 185.4635294117647, 'BMI <= 30.7\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(325.38007033997656, 172.6729411764706, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(331.66002344665884, 172.6729411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
plt.figure(figsize=(20,20))
tree = plot_tree(model, feature_names=feature_names,
                filled=True,
                fontsize=10)

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_tree = export_graphviz(model, feature_names= feature_names,filled=True)
graphviz.Source(dot_tree)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     169     try:
# --> 170         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     171     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1310             try:
# -> 1311                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1312                                          # no special security
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\graphviz\files.py in _repr_svg_(self)
#     139
#     140     def _repr_svg_(self):
# --> 141         return self.pipe(format='svg').decode(self._encoding)
#     142
#     143     def pipe(self, format=None, renderer=None, formatter=None, quiet=False):
#
# ~\anaconda3\lib\site-packages\graphviz\files.py in pipe(self, format, renderer, formatter, quiet)
#     164         data = self.source.encode(self._encoding)
#     165
# --> 166         out = backend.pipe(self._engine, format, data,
#     167                            renderer=renderer, formatter=formatter,
#     168                            quiet=quiet)
#
# ~\anaconda3\lib\site-packages\graphviz\backend.py in pipe(engine, format, data, renderer, formatter, quiet)
#     266     """
#     267     cmd, _ = command(engine, format, None, renderer, formatter)
# --> 268     out, _ = run(cmd, input=data, capture_output=True, check=True, quiet=quiet)
#     269     return out
#     270
#
# ~\anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     171     except OSError as e:
#     172         if e.errno == errno.ENOENT:
# --> 173             raise ExecutableNotFound(cmd) from e
#     174         else:
#     175             raise
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH
