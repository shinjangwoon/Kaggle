# %%
import pandas as pd

# %%
df_train = pd.read_csv('./pubg-finish-placement-prediction/train_V2.csv')
df_test = pd.read_csv('./pubg-finish-placement-prediction/test_V2.csv')

# %%
df_train.to_pickle('train.pkl')
df_test.to_pickle('test.pkl')

# %%
df_1 = pd.read_pickle('train.pkl')
df_2 = pd.read_pickle('test.pkl')

# %%
train = pd.read_csv('train_Sampleing.csv')
train.to_pickle('train_Sampling.pkl')

# %%
df = pd.read_pickle('train_Sampling.pkl')

# %%
df.head()
# Out:
#    Unnamed: 0              Id         groupId         matchId  assists  \
# 0           0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0
# 1           1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0
# 2           2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1
# 3           3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0
# 4           4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0
#
#    boosts  damageDealt  DBNOs  headshotKills  heals  ...  roadKills  \
# 0       0         0.00      0              0      0  ...          0
# 1       0        91.47      0              0      0  ...          0
# 2       0        68.00      0              0      0  ...          0
# 3       0        32.90      0              0      0  ...          0
# 4       0       100.00      0              0      0  ...          0
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance  weaponsAcquired  \
# 0          0.00          0                0        244.80                1
# 1         11.04          0                0       1434.00                5
# 2          0.00          0                0        161.80                2
# 3          0.00          0                0        202.70                3
# 4          0.00          0                0         49.75                2
#
#    winPoints  winPlacePerc  totalDistance  teamSize
# 0       1466        0.4444       244.8000         4
# 1          0        0.6400      1445.0445         4
# 2          0        0.7755       161.8000         2
# 3          0        0.1667       202.7000         1
# 4          0        0.1875        49.7500         1
#
# [5 rows x 32 columns]
